# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

import cartopy.crs as ccrs

# %%
fin1 = xr.open_dataset('LUH2_states_transitions_management.timeseries_4x5_hist_steadystate_1850_21oct2024.nc')
fin2 = xr.open_dataset('LUH2_states_transitions_management.timeseries_4x5_hist_steadystate_2000_29oct2024.nc')
fin3 = xr.open_dataset('LUH2_states_transitions_management.timeseries_4x5_hist_steadystate_2014_29oct2024.nc')

# %%
(fin1['secyf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.005, cmap='Reds')

# %%
(fin2['secyf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.005, cmap='Reds')

# %%
(fin3['secyf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.005, cmap='Reds')

# %%
(fin1['secmf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.01, cmap='Blues')

# %%
(fin2['secmf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.01, cmap='Blues')

# %%
(fin3['secmf_harv'].mean(dim='time')).plot(levels=np.arange(20)*0.01, cmap='Blues')

# %%
(fin1['secdf'].mean(dim='time') + fin1['secdn'].mean(dim='time')).plot()

# %%
(fin2['secdf'].mean(dim='time') + fin2['secdn'].mean(dim='time')).plot()

# %%
(fin3['secdf'].mean(dim='time') + fin3['secdn'].mean(dim='time')).plot()
